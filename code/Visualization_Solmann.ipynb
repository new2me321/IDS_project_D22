# %%
import pandas as pd

atlantic = pd.read_csv('atlantic.csv')
pacific = pd.read_csv('pacific.csv')

columns = []
for col_name in atlantic.columns: 
    columns.append(col_name)

atlantic_lite = atlantic.dropna()
pacific_lite = pacific.dropna()

atlantic_full = atlantic[atlantic['Moderate Wind NW'] != -999]
pacific_full = pacific[pacific['Moderate Wind NW'] != -999]

atlantic_place = atlantic
#atlantic_place['Latitude'] = atlantic_place['Latitude'].astype('|S')
print(atlantic_place.head())
atlantic_place = atlantic_place[atlantic_place['Latitude'].str[4] == 'N']
atlantic_place['Real Latitude'] = atlantic_place['Latitude']
atlantic_place.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 0     94.8W            80              -999  ...         -999         -999
# 1     95.4W            80              -999  ...         -999         -999
# 2     96.0W            80              -999  ...         -999         -999
# 3     96.5W            80              -999  ...         -999         -999
# 4     96.8W            80              -999  ...         -999         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    High Wind NE  High Wind SE  High Wind SW  High Wind NW
# 0          -999          -999          -999          -999
# 1          -999          -999          -999          -999
# 2          -999          -999          -999          -999
# 3          -999          -999          -999          -999
# 4          -999          -999          -999          -999
#
# [5 rows x 22 columns]
# C:\Users\solmann\AppData\Local\Temp/ipykernel_5440/2022136120.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlantic_place['Real Latitude'] = atlantic_place['Latitude']
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind NW  \
# 0     94.8W            80              -999  ...         -999
# 1     95.4W            80              -999  ...         -999
# 2     96.0W            80              -999  ...         -999
# 3     96.5W            80              -999  ...         -999
# 4     96.8W            80              -999  ...         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    High Wind NE  High Wind SE  High Wind SW  High Wind NW  Real Latitude
# 0          -999          -999          -999          -999          28.0N
# 1          -999          -999          -999          -999          28.0N
# 2          -999          -999          -999          -999          28.0N
# 3          -999          -999          -999          -999          28.1N
# 4          -999          -999          -999          -999          28.2N
#
# [5 rows x 23 columns]

# %%
atlantic_place.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind NW  \
# 0     94.8W            80              -999  ...         -999
# 1     95.4W            80              -999  ...         -999
# 2     96.0W            80              -999  ...         -999
# 3     96.5W            80              -999  ...         -999
# 4     96.8W            80              -999  ...         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    High Wind NE  High Wind SE  High Wind SW  High Wind NW  Real Latitude
# 0          -999          -999          -999          -999          28.0N
# 1          -999          -999          -999          -999          28.0N
# 2          -999          -999          -999          -999          28.0N
# 3          -999          -999          -999          -999          28.1N
# 4          -999          -999          -999          -999          28.2N
#
# [5 rows x 23 columns]

# %%
#print(atlantic.head())
print(atlantic.shape)
print(atlantic_full.shape)

print(atlantic_lite.shape)
# Out:
# (49105, 22)
# (5921, 22)
# (49105, 22)

# %%
#print(pacific.head())
print(pacific.shape)
print(pacific_full.shape)

print(pacific_lite.shape)
# Out:
# (26137, 22)
# (6387, 22)
# (26137, 22)

# %%
print(atlantic['Latitude'].iloc[1])
# Out:
# 28.0N

# %%
#Where useful stuff starts

def get_latitude(original_lat):
    
    hemisphere = original_lat[-1]
    lat = float(original_lat[:-1])
    
    if hemisphere == "S":
        lat = 0 - lat
        
    if abs(lat) > 90:
        lat = 0
        
    return lat
  

for i in range(60):
    print(atlantic['Latitude'].iloc[i])
    print(get_latitude(atlantic['Latitude'].iloc[i]))
    i += 1
# Out:
# 28.0N
# 28.0
# 28.0N
# 28.0
# 28.0N
# 28.0
# 28.1N
# 28.1
# 28.2N
# 28.2
# 28.2N
# 28.2
# 28.3N
# 28.3
# 28.4N
# 28.4
# 28.6N
# 28.6
# 29.0N
# 29.0
# 29.5N
# 29.5
# 30.0N
# 30.0
# 30.5N
# 30.5
# 31.0N
# 31.0
# 22.2N
# 22.2
# 12.0N
# 12.0
# 13.4N
# 13.4
# 13.7N
# 13.7
# 14.0N
# 14.0
# 14.4N
# 14.4
# 14.9N
# 14.9
# 15.4N
# 15.4
# 15.9N
# 15.9
# 16.1N
# 16.1
# 16.6N
# 16.6
# 16.9N
# 16.9
# 17.2N
# 17.2
# 17.6N
# 17.6
# 18.0N
# 18.0
# 18.4N
# 18.4
# 18.9N
# 18.9
# 19.4N
# 19.4
# 19.9N
# 19.9
# 20.5N
# 20.5
# 21.2N
# 21.2
# 21.9N
# 21.9
# 22.6N
# 22.6
# 23.2N
# 23.2
# 23.9N
# 23.9
# 24.4N
# 24.4
# 25.0N
# 25.0
# 25.6N
# 25.6
# 26.2N
# 26.2
# 26.8N
# 26.8
# 27.4N
# 27.4
# 28.0N
# 28.0
# 28.5N
# 28.5
# 29.6N
# 29.6
# 30.1N
# 30.1
# 30.7N
# 30.7
# 31.6N
# 31.6
# 32.5N
# 32.5
# 33.4N
# 33.4
# 34.0N
# 34.0
# 34.8N
# 34.8
# 35.8N
# 35.8
# 36.8N
# 36.8
# 37.8N
# 37.8
# 38.9N
# 38.9
# 40.0N
# 40.0

# %%
def get_longitude(original_long):
    
    hemisphere = original_long[-1]
    long = float(original_long[:-1])
    
    if hemisphere == "W":
        long = 0 - long
        
    if abs(long) > 180:
        long = 0
        
    return long


def get_longitude2(original_long):
    
    hemisphere = original_long[-1]
    long = float(original_long[:-1])
    
    if hemisphere == "W":
        long = 180 + 180 - long

        
    #if abs(long) > 180:
        #long = 0
        
    return long


for i in range(60):
    print(atlantic['Longitude'].iloc[i])
    print(get_longitude(atlantic['Longitude'].iloc[i]))
    i += 1
# Out:
# 94.8W
# -94.8
# 95.4W
# -95.4
# 96.0W
# -96.0
# 96.5W
# -96.5
# 96.8W
# -96.8
# 97.0W
# -97.0
# 97.6W
# -97.6
# 98.3W
# -98.3
# 98.9W
# -98.9
# 99.4W
# -99.4
# 99.8W
# -99.8
# 100.0W
# -100.0
# 100.1W
# -100.1
# 100.2W
# -100.2
# 97.6W
# -97.6
# 60.0W
# -60.0
# 48.0W
# -48.0
# 49.5W
# -49.5
# 51.0W
# -51.0
# 52.8W
# -52.8
# 54.6W
# -54.6
# 56.5W
# -56.5
# 58.5W
# -58.5
# 60.4W
# -60.4
# 62.5W
# -62.5
# 64.1W
# -64.1
# 66.0W
# -66.0
# 67.6W
# -67.6
# 69.3W
# -69.3
# 71.1W
# -71.1
# 72.6W
# -72.6
# 74.3W
# -74.3
# 75.9W
# -75.9
# 77.6W
# -77.6
# 79.0W
# -79.0
# 80.4W
# -80.4
# 81.4W
# -81.4
# 82.5W
# -82.5
# 83.6W
# -83.6
# 84.3W
# -84.3
# 84.9W
# -84.9
# 85.5W
# -85.5
# 86.0W
# -86.0
# 86.3W
# -86.3
# 86.5W
# -86.5
# 86.6W
# -86.6
# 86.6W
# -86.6
# 86.1W
# -86.1
# 85.7W
# -85.7
# 85.1W
# -85.1
# 84.1W
# -84.1
# 83.0W
# -83.0
# 81.4W
# -81.4
# 80.0W
# -80.0
# 78.6W
# -78.6
# 77.0W
# -77.0
# 75.1W
# -75.1
# 73.6W
# -73.6
# 71.8W
# -71.8
# 70.0W
# -70.0

# %%
atlantic["Real Latitude"] = 0
atlantic["Real Longitude"] = 0

for i in range(atlantic.shape[0]):
    atlantic["Real Latitude"][i] = get_latitude((atlantic['Latitude'].iloc[i]))

for i in range(atlantic.shape[0]):
    atlantic["Real Longitude"][i] = get_longitude((atlantic['Longitude'].iloc[i]))


atlantic.head()
# Out:
# C:\Users\solmann\AppData\Local\Temp/ipykernel_5440/2375131741.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlantic["Real Latitude"][i] = get_latitude((atlantic['Latitude'].iloc[i]))
# C:\Users\solmann\AppData\Local\Temp/ipykernel_5440/2375131741.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlantic["Real Longitude"][i] = get_longitude((atlantic['Longitude'].iloc[i]))
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Moderate Wind NE  \
# 0     94.8W            80              -999  ...              -999
# 1     95.4W            80              -999  ...              -999
# 2     96.0W            80              -999  ...              -999
# 3     96.5W            80              -999  ...              -999
# 4     96.8W            80              -999  ...              -999
#
#    Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  High Wind NE  \
# 0              -999              -999              -999          -999
# 1              -999              -999              -999          -999
# 2              -999              -999              -999          -999
# 3              -999              -999              -999          -999
# 4              -999              -999              -999          -999
#
#    High Wind SE  High Wind SW  High Wind NW  Real Latitude  Real Longitude
# 0          -999          -999          -999             28             -94
# 1          -999          -999          -999             28             -95
# 2          -999          -999          -999             28             -96
# 3          -999          -999          -999             28             -96
# 4          -999          -999          -999             28             -96
#
# [5 rows x 24 columns]

# %%
pacific["Real Latitude"] = 0
pacific["Real Longitude"] = 0

for i in range(pacific.shape[0]):
    pacific["Real Latitude"][i] = get_latitude((pacific['Latitude'].iloc[i]))

for i in range(pacific.shape[0]):
    pacific["Real Longitude"][i] = get_longitude2((pacific['Longitude'].iloc[i]))


pacific.head()
# Out:
# C:\Users\solmann\AppData\Local\Temp/ipykernel_5440/4010040108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pacific["Real Latitude"][i] = get_latitude((pacific['Latitude'].iloc[i]))
# C:\Users\solmann\AppData\Local\Temp/ipykernel_5440/4010040108.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pacific["Real Longitude"][i] = get_longitude2((pacific['Longitude'].iloc[i]))
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  EP011949              UNNAMED  19490611     0           TS    20.2N
# 1  EP011949              UNNAMED  19490611   600           TS    20.2N
# 2  EP011949              UNNAMED  19490611  1200           TS    20.2N
# 3  EP011949              UNNAMED  19490611  1800           TS    20.3N
# 4  EP011949              UNNAMED  19490612     0           TS    20.4N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Moderate Wind NE  \
# 0    106.3W            45              -999  ...              -999
# 1    106.4W            45              -999  ...              -999
# 2    106.7W            45              -999  ...              -999
# 3    107.7W            45              -999  ...              -999
# 4    108.6W            45              -999  ...              -999
#
#    Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  High Wind NE  \
# 0              -999              -999              -999          -999
# 1              -999              -999              -999          -999
# 2              -999              -999              -999          -999
# 3              -999              -999              -999          -999
# 4              -999              -999              -999          -999
#
#    High Wind SE  High Wind SW  High Wind NW  Real Latitude  Real Longitude
# 0          -999          -999          -999             20             253
# 1          -999          -999          -999             20             253
# 2          -999          -999          -999             20             253
# 3          -999          -999          -999             20             252
# 4          -999          -999          -999             20             251
#
# [5 rows x 24 columns]

# %%
#gonna try to visualize where they be

import seaborn
from matplotlib import pyplot as plt


plt.gcf().set_size_inches((20, 20)) 
seaborn.scatterplot(atlantic['Real Longitude'],atlantic['Real Latitude'], hue=atlantic['Maximum Wind'])
# Out:
# C:\Users\solmann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Real Longitude', ylabel='Real Latitude'>

# %%
plt.gcf().set_size_inches((20, 20)) 
seaborn.scatterplot(pacific['Real Longitude'],pacific['Real Latitude'], hue=pacific['Maximum Wind'])
# Out:
# C:\Users\solmann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Real Longitude', ylabel='Real Latitude'>
